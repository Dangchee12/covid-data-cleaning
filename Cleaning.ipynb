# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("20220123 Global Covid Data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156546 entries, 0 to 156545
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    156546 non-null  object
#  1   continent                                   147136 non-null  object
#  2   location                                    156546 non-null  object
#  3   date                                        156546 non-null  object
#  4   total_cases                                 153714 non-null  float64
#  5   new_cases                                   153649 non-null  float64
#  6   new_cases_smoothed                          152498 non-null  float64
#  7   total_deaths                                136289 non-null  float64
#  8   new_deaths                                  136450 non-null  float64
# ...

# %%
data_required = ["location", "date", "new_cases_smoothed", "new_deaths_smoothed", "new_cases_smoothed_per_million", "new_deaths_smoothed_per_million", "icu_patients_per_million", "hosp_patients_per_million", "weekly_icu_admissions_per_million", "weekly_hosp_admissions_per_million", "new_tests_smoothed_per_thousand", "people_fully_vaccinated_per_hundred", "total_boosters_per_hundred", "new_vaccinations_smoothed_per_million", "stringency_index", "population"]
df = df[data_required]
df.head()
# Out:
#       location        date  new_cases_smoothed  new_deaths_smoothed  \
# 0  Afghanistan  2020-02-24                 NaN                  NaN
# 1  Afghanistan  2020-02-25                 NaN                  NaN
# 2  Afghanistan  2020-02-26                 NaN                  NaN
# 3  Afghanistan  2020-02-27                 NaN                  NaN
# 4  Afghanistan  2020-02-28                 NaN                  NaN
#
#    new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
#    icu_patients_per_million  hosp_patients_per_million  \
# 0                       NaN                        NaN
# ...

# %%
countries = ["United Kingdom", "Denmark", "Singapore", "Malaysia", "United States", "South Africa"]
df = df[df.location.isin(countries)]
df.head()
# Out:
#       location        date  new_cases_smoothed  new_deaths_smoothed  \
# 38169  Denmark  2020-02-02                 NaN                  NaN
# 38170  Denmark  2020-02-03                 NaN                  NaN
# 38171  Denmark  2020-02-04                 NaN                  NaN
# 38172  Denmark  2020-02-05                 NaN                  NaN
# 38173  Denmark  2020-02-06                 NaN                  NaN
#
#        new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 38169                             NaN                              NaN
# 38170                             NaN                              NaN
# 38171                             NaN                              NaN
# 38172                             NaN                              NaN
# 38173                             NaN                              NaN
#
#        icu_patients_per_million  hosp_patients_per_million  \
# 38169                       NaN                        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4353 entries, 38169 to 148719
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   location                               4353 non-null   object
#  1   date                                   4353 non-null   object
#  2   new_cases_smoothed                     4268 non-null   float64
#  3   new_deaths_smoothed                    4077 non-null   float64
#  4   new_cases_smoothed_per_million         4268 non-null   float64
#  5   new_deaths_smoothed_per_million        4077 non-null   float64
#  6   icu_patients_per_million               3249 non-null   float64
#  7   hosp_patients_per_million              3193 non-null   float64
#  8   weekly_icu_admissions_per_million      0 non-null      float64
#  9   weekly_hosp_admissions_per_million     2641 non-null   float64
# ...

# %%
df_uk = df[(df.date > "2021-04-30") & (df.location == "United Kingdom")]
df_malaysia = df[(df.date > "2021-04-30") & (df.location == "Malaysia")]
df_singapore = df[(df.date > "2021-04-30") & (df.location == "Singapore")]
df_denmark = df[(df.date > "2021-04-30") & (df.location == "Denmark")]
df_southafrica = df[(df.date > "2021-04-30") & (df.location == "South Africa")]
df_us = df[(df.date > "2021-04-30") & (df.location == "United States")]

# %%
frames = [df_uk, df_malaysia, df_singapore, df_denmark, df_southafrica, df_us]
country = ["uk", "malaysia", "singapore", "denmark", "southafrica", "us"]
i = 0
for frame in frames:
    frame.to_csv(country[i] + ".csv")
    i+=1

# %%
from datetime import date, timedelta

df_uk = df_uk.set_index("date")

sdate = date(2021,9,1)
edate = date(2021,11,30)
period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
df_uk.drop(labels=period, axis=0, inplace=True)

df_uk["wave"] = "delta"
sdate = date(2021,12,1)
edate = date.today() - timedelta(days=1)

period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
df_uk.at[period, "wave"] = "omicron"

df_uk.reset_index(inplace=True)
df_uk.head()
# Out:
#          date        location  new_cases_smoothed  new_deaths_smoothed  \
# 0  2021-06-01  United Kingdom            3304.143                6.143
# 1  2021-06-02  United Kingdom            3486.143                6.571
# 2  2021-06-03  United Kingdom            3743.143                7.714
# 3  2021-06-04  United Kingdom            4044.857                7.857
# 4  2021-06-05  United Kingdom            4389.286                8.714
#
#    new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 0                          48.443                            0.090
# 1                          51.111                            0.096
# 2                          54.879                            0.113
# 3                          59.303                            0.115
# 4                          64.352                            0.128
#
#    icu_patients_per_million  hosp_patients_per_million  \
# 0                     1.994                     13.635
# ...

# %%
df_denmark = df_denmark.set_index("date")

sdate = date(2021,9,16)
edate = date(2021,11,30)
period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
#period
df_denmark.drop(labels=period, axis=0, inplace=True)

df_denmark["wave"] = "delta"
sdate = date(2021,12,1)
edate = date.today() - timedelta(days=1)

period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
df_denmark.at[period, "wave"] = "omicron"

df_denmark.reset_index(inplace=True)
df_denmark.head()
# Out:
#          date location  new_cases_smoothed  new_deaths_smoothed  \
# 0  2021-07-01  Denmark             257.143                0.571
# 1  2021-07-02  Denmark             272.000                0.714
# 2  2021-07-03  Denmark             308.000                0.857
# 3  2021-07-04  Denmark             339.143                0.714
# 4  2021-07-05  Denmark             365.714                0.571
#
#    new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 0                          44.234                            0.098
# 1                          46.789                            0.123
# 2                          52.982                            0.147
# 3                          58.339                            0.123
# 4                          62.910                            0.098
#
#    icu_patients_per_million  hosp_patients_per_million  \
# 0                     2.064                      8.945
# 1                     1.892                      8.257
# ...

# %%
df_singapore = df_singapore.set_index("date")

sdate = date(2021,12,2)
edate = date(2021,12,25)
period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
#period
df_singapore.drop(labels=period, axis=0, inplace=True)

df_singapore["wave"] = "delta"
sdate = date(2021,12,26)
edate = date.today() - timedelta(days=1)

period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
df_singapore.at[period, "wave"] = "omicron"

df_singapore.reset_index(inplace=True)
df_singapore.head()
# Out:
#          date   location  new_cases_smoothed  new_deaths_smoothed  \
# 0  2021-09-01  Singapore             141.143                0.429
# 1  2021-09-02  Singapore             151.857                0.429
# 2  2021-09-03  Singapore             183.143                0.429
# 3  2021-09-04  Singapore             185.429                0.000
# 4  2021-09-05  Singapore             212.714                0.000
#
#    new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 0                          25.881                            0.079
# 1                          27.845                            0.079
# 2                          33.582                            0.079
# 3                          34.001                            0.000
# 4                          39.004                            0.000
#
#    icu_patients_per_million  hosp_patients_per_million  \
# 0                     0.917                     90.582
# ...

# %%
df_southafrica = df_southafrica.set_index("date")

sdate = date(2021,10,1)
edate = date(2021,11,21)
period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
#period
df_southafrica.drop(labels=period, axis=0, inplace=True)

df_southafrica["wave"] = "delta"
sdate = date(2021,11,22)
edate = date.today() - timedelta(days=1)

period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
df_southafrica.at[period, "wave"] = "omicron"

df_southafrica.reset_index(inplace=True)
df_southafrica.head()
# Out:
#          date      location  new_cases_smoothed  new_deaths_smoothed  \
# 0  2021-05-01  South Africa            1210.286               40.143
# 1  2021-05-02  South Africa            1227.571               38.429
# 2  2021-05-03  South Africa            1234.429               38.000
# 3  2021-05-04  South Africa            1278.286               39.143
# 4  2021-05-05  South Africa            1395.857               38.857
#
#    new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 0                          20.157                            0.669
# 1                          20.445                            0.640
# 2                          20.559                            0.633
# 3                          21.290                            0.652
# 4                          23.248                            0.647
#
#    icu_patients_per_million  hosp_patients_per_million  \
# 0                       NaN                        NaN
# ...

# %%
df_us = df_us.set_index("date")

sdate = date(2021,11,1)
edate = date(2021,12,13)
period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
#period
df_us.drop(labels=period, axis=0, inplace=True)

df_us["wave"] = "delta"
sdate = date(2021,12,14)
edate = date.today() - timedelta(days=1)

period = pd.date_range(sdate,edate,freq='d').strftime('%Y-%m-%d').tolist()
df_us.at[period, "wave"] = "omicron"

df_us.reset_index(inplace=True)
df_us.head()
# Out:
#          date       location  new_cases_smoothed  new_deaths_smoothed  \
# 0  2021-07-01  United States           12726.429              260.000
# 1  2021-07-02  United States           13484.000              247.429
# 2  2021-07-03  United States           12888.857              237.429
# 3  2021-07-04  United States           12828.000              232.857
# 4  2021-07-05  United States           12122.286              229.714
#
#    new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 0                          38.227                            0.781
# 1                          40.503                            0.743
# 2                          38.715                            0.713
# 3                          38.532                            0.699
# 4                          36.413                            0.690
#
#    icu_patients_per_million  hosp_patients_per_million  \
# 0                    10.856                     38.637
# ...

# %%
df_malaysia = df_malaysia[df_malaysia.date < "2021-11-01"]
df_malaysia["wave"] = "delta"
df_malaysia.reset_index(inplace=True)
df_malaysia.head()
# Out:
#    index  location        date  new_cases_smoothed  new_deaths_smoothed  \
# 0  88140  Malaysia  2021-05-01            3048.857               13.571
# 1  88141  Malaysia  2021-05-02            3152.857               13.857
# 2  88142  Malaysia  2021-05-03            3113.429               14.571
# 3  88143  Malaysia  2021-05-04            3168.714               16.000
# 4  88144  Malaysia  2021-05-05            3254.714               16.286
#
#    new_cases_smoothed_per_million  new_deaths_smoothed_per_million  \
# 0                          93.020                            0.414
# 1                          96.194                            0.423
# 2                          94.991                            0.445
# 3                          96.677                            0.488
# 4                          99.301                            0.497
#
#    icu_patients_per_million  hosp_patients_per_million  \
# 0                    13.302                     94.550
# ...

# %%
frames = [df_us, df_uk, df_denmark, df_singapore, df_malaysia, df_southafrica]
combined = pd.concat(frames)
combined.to_csv("cleaned_data.csv")
